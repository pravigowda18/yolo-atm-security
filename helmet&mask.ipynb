# %%
# prompt: connect to drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone Ultralytics and install requirements
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 859.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/dataset.zip"  # Replace with your uploaded file name
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("HelmetMaskDataset")

# %%
from ultralytics import YOLO

# Load a pre-trained model and train
model = YOLO("yolov8n.pt")  # You can use yolov8s.pt, yolov8m.pt etc.

model.train(data="data.yaml",
            epochs=50,
            imgsz=640,
            batch=16)
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
img = "/content/runs/detect/train4/F1_curve.png"
Image(filename = img,width=600)

# %%
img = "/content/runs/detect/train4/PR_curve.png"
Image(filename = img,width=600)

# %%
img = "/content/runs/detect/train4/confusion_matrix.png"
Image(filename = img,width=600)

# %%
img = "/content/runs/detect/train4/confusion_matrix_normalized.png"
Image(filename = img,width=600)

# %%
img = "/content/runs/detect/train4/results.png"
Image(filename = img,width=600)

# %%
img = "/content/runs/detect/train4/train_batch1281.jpg"
Image(filename = img,width=600)

# %%
model = YOLO("/content/runs/detect/train4/weights/best.pt")

model.predict(source = "/content/HelmetMaskDataset/dataset/val/images/img_1.jpg", show = True, save=True)
# Out:
# image 1/1 /content/HelmetMaskDataset/dataset/val/images/img_1.jpg: 448x640 1 mask, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'no_msk_hlmt', 1: 'mask', 2: 'helmet'}
#  obb: None
#  orig_img: array([[[ 17,  21,  10],
#          [ 17,  21,  10],
#          [ 17,  21,  10],
#          ...,
#          [ 43,  43,  29],
#          [ 42,  42,  28],
#          [ 42,  42,  28]],
#
#         [[ 17,  21,  10],
#          [ 17,  21,  10],
#          [ 17,  21,  10],
#          ...,
#          [ 43,  43,  29],
#          [ 43,  43,  29],
#          [ 42,  42,  28]],
#
#         [[ 17,  21,  10],
#          [ 17,  21,  10],
#          [ 17,  21,  10],
#          ...,
#          [ 44,  44,  30],
#          [ 43,  43,  29],
# ...

# %%
model = YOLO("/content/runs/detect/train4/weights/best.pt")

model.predict(source = "/content/HelmetMaskDataset/dataset/val/images/img_12.jpg", show = True, save=True)
# Out:
# image 1/1 /content/HelmetMaskDataset/dataset/val/images/img_12.jpg: 288x640 1 mask, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'no_msk_hlmt', 1: 'mask', 2: 'helmet'}
#  obb: None
#  orig_img: array([[[ 72, 210, 198],
#          [ 70, 210, 197],
#          [ 68, 209, 194],
#          ...,
#          [150, 239, 229],
#          [150, 242, 231],
#          [151, 243, 232]],
#
#         [[ 72, 210, 198],
#          [ 71, 211, 198],
#          [ 68, 211, 196],
#          ...,
#          [145, 237, 226],
#          [145, 237, 226],
#          [143, 237, 226]],
#
#         [[ 73, 213, 200],
#          [ 71, 213, 200],
#          [ 69, 214, 199],
#          ...,
#          [134, 231, 217],
#          [132, 229, 215],
# ...
